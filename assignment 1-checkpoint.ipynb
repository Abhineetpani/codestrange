# %%
x='python"fun'
print(x)
# Out:
# python"fun

# %%
r=5
c=2*3.14*r
a=4*3.14*(r**2)
v=(4/3)*3.14*r**3
print(c)
print(a)
print(v)
# Out:
# 31.400000000000002
# 314.0
# 523.3333333333334

# %%
seconds=45678
seconds=seconds%(24*3600)
hours=seconds//3600
seconds%=3600
minutes=seconds//60
seconds%=60
print(hours,minutes,seconds)
# Out:
# 12 41 18

# %%
x=100
y=300
print(x and y)
# Out:
# 100
